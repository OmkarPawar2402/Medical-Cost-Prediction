# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    ------------------------- -------------- 6.3/9.9 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 30.3 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 94.5 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df=df.drop_duplicates(keep="first")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.distplot(df["charges"])
plt.show()

# %%
sns.countplot(data=df,x="region",hue="sex",palette="deep")
plt.show()

# %%
sns.countplot(data=df,x="smoker",hue="sex",palette="deep")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
le_sex=LabelEncoder()
le_smoker=LabelEncoder()
le_region=LabelEncoder()

# %%
df["sex"]=le_sex.fit_transform(df["sex"])
df["smoker"]=le_smoker.fit_transform(df["smoker"])
df["region"]=le_region.fit_transform(df["region"])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#features And target
X=df.drop("charges",axis=1)
Y=df["charges"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model=RandomForestRegressor(n_estimators=200,random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
print("R2_score:",r2_score(Y_test,y_pred))
# Out:
# R2_score: 0.8835647538322066

# %%
import pickle

# %%
pickle.dump({"model":model,"sex_encoder":le_sex,"smoker_encoder":le_smoker,"region_encoder":le_region},open("model.pkl","wb"))
print("Model Saved Successfully")
# Out:
# Model Saved Successfully
